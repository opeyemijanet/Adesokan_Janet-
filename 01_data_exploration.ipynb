# %% [markdown]
# <a href="https://colab.research.google.com/github/opeyemijanet/Adesokan_Janet-/blob/main/01_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#TECH4DEV PROJECT

# %%
#FOOD DEMAND FORECASTING MODEL
#================================
#Purpose: Predict daily/weekly food demand for restaurants, caterers, or food businesses
#Business Value: Reduce waste, optimize inventory, improve profitability
#Target Users: Restaurant owners, catering services, food delivery platforms
